# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
feature0 = pd.read_csv("feature0.csv")[0:1380]
feature1 = pd.read_csv("feature1.csv")[0:1380]
feature2 = pd.read_csv("feature2.csv")[0:1380]
feature3 = pd.read_csv("feature3.csv")[0:1380]

# %%
feature0
# Out:
#       index  172.20.1.164  172.20.2.148  172.20.2.151  172.20.1.170  \
# 0         1            54            38            44            54
# 1         2            44            49            42            49
# 2         3            41            37            42            47
# 3         4            43            29            53            45
# 4         5            57            32            26            48
# ...     ...           ...           ...           ...           ...
# 1375   1376            40            47            40            89
# 1376   1377            45            48            36            62
# 1377   1378            40            52            39            56
# 1378   1379            67            26            27            73
# 1379   1380            49            48            43            48
#
#       172.20.2.149  172.20.1.165  172.20.1.171  172.20.2.152  172.20.1.166  \
# ...

# %%
feature0_copy1 = feature0.copy()
feature0_copy1["index"] = feature0["index"]+1380
feature0_copy1.index = feature0.index+1380

feature1_copy1 = feature1.copy()
feature1_copy1["index"] = feature1["index"]+1380
feature1_copy1.index = feature1.index+1380

feature2_copy1 = feature2.copy()
feature2_copy1["index"] = feature2["index"]+1380
feature2_copy1.index = feature2.index+1380

feature3_copy1 = feature3.copy()
feature3_copy1["index"] = feature3["index"]+1380
feature3_copy1.index = feature3.index+1380

# feature0_copy2 = feature0.copy()
# feature0_copy2["index"] = feature0["index"]+2760
# feature0_copy2.index = feature0.index+2760

# feature1_copy2 = feature1.copy()
# feature1_copy2["index"] = feature1["index"]+2760
# feature1_copy2.index = feature1.index+2760

# feature2_copy2 = feature2.copy()
# feature2_copy2["index"] = feature2["index"]+2760
# feature2_copy2.index = feature2.index+2760

# feature3_copy2 = feature3.copy()
# feature3_copy2["index"] = feature3["index"]+2760
# feature3_copy2.index = feature3.index+2760

# %%
feature0_copy2
# Out:
#       index  172.20.1.164  172.20.2.148  172.20.2.151  172.20.1.170  \
# 2760   2761            54            38            44            54
# 2761   2762            44            49            42            49
# 2762   2763            41            37            42            47
# 2763   2764            43            29            53            45
# 2764   2765            57            32            26            48
# ...     ...           ...           ...           ...           ...
# 4135   4136            40            47            40            89
# 4136   4137            45            48            36            62
# 4137   4138            40            52            39            56
# 4138   4139            67            26            27            73
# 4139   4140            49            48            43            48
#
#       172.20.2.149  172.20.1.165  172.20.1.171  172.20.2.152  172.20.1.166  \
# ...

# %%
feature0_final = feature0.append(feature0_copy1)
# feature0_final = feature0_final.append(feature0_copy2)

feature1_final = feature1.append(feature1_copy1)
# feature1_final = feature1_final.append(feature1_copy2)

feature2_final = feature2.append(feature2_copy1)
# feature2_final = feature2_final.append(feature2_copy2)

feature3_final = feature3.append(feature3_copy1)
# feature3_final = feature3_final.append(feature3_copy2)

# %%
plt.plot(feature2_final)

# %%
feature0_final.to_csv("feature0.csv",index=False)
feature1_final.to_csv("feature1.csv",index=False)
feature2_final.to_csv("feature2.csv",index=False)
feature3_final.to_csv("feature3.csv",index=False)
